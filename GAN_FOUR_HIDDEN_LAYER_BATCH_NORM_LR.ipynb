# %% [markdown]
# This is a two hidden layer GAN with batch normalization based off of the "Intro to GANs" Lesson from the Udacity Deep Learning Foundations Nanodegree: https://github.com/udacity/deep-learning/blob/master/gan_mnist/Intro_to_GANs_Solution.ipynb

# %%
# %matplotlib inline
import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    
    return inputs_real, inputs_z

# %%
def generator(z, out_dim, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('generator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        h1 = tf.contrib.layers.batch_norm(h1)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        h2 = tf.layers.dense(h1, n_units*2, activation=None)
        h2 = tf.contrib.layers.batch_norm(h2)
        h2 = tf.maximum(alpha * h2, h2)
        h3 = tf.layers.dense(h2, n_units*3, activation=None)
        h3 = tf.contrib.layers.batch_norm(h3)
        # Leaky ReLU
        h3 = tf.maximum(alpha * h3, h3)
        h4 = tf.layers.dense(h3, n_units*4, activation=None)
        h4 = tf.contrib.layers.batch_norm(h4)
        h4 = tf.maximum(alpha * h4, h4)
        
        logits = tf.layers.dense(h4, out_dim)
        out = tf.tanh(logits)
        
        return out, logits

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('discriminator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        logits = tf.layers.dense(h1, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# <h2>Hyperparameters</h2>

# %%
input_size = 784
z_size = 100
alpha = 0.01
smooth = 0.1

# %%
tf.reset_default_graph()
input_real, input_z = model_inputs(input_size, z_size)

g_model, g_logits = generator(input_z, input_size)
d_model_real, d_logits_real = discriminator(input_real)
d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

# %%
d_loss_real = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                          labels=tf.ones_like(d_logits_real) * (1 - smooth)))
d_loss_fake = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                          labels=tf.zeros_like(d_logits_real)))
d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                     labels=tf.ones_like(d_logits_fake)))

# %%
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer().minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer().minimize(g_loss, var_list=g_vars)

# %%
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %%
batch_size = 100
epochs = 100
samples = []
losses = []
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))          
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        losses.append((train_loss_d, train_loss_g))
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples, _ = sess.run(
                       generator(input_z, input_size, reuse=True),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/100... Discriminator Loss: 0.4966... Generator Loss: 3.5573
# Epoch 2/100... Discriminator Loss: 1.6439... Generator Loss: 0.9607
# Epoch 3/100... Discriminator Loss: 2.4957... Generator Loss: 0.7258
# Epoch 4/100... Discriminator Loss: 1.9280... Generator Loss: 1.1681
# Epoch 5/100... Discriminator Loss: 1.9123... Generator Loss: 0.5605
# Epoch 6/100... Discriminator Loss: 1.3123... Generator Loss: 0.8715
# Epoch 7/100... Discriminator Loss: 1.0830... Generator Loss: 1.0646
# Epoch 8/100... Discriminator Loss: 2.6067... Generator Loss: 0.6839
# Epoch 9/100... Discriminator Loss: 2.1294... Generator Loss: 0.6343
# Epoch 10/100... Discriminator Loss: 1.3522... Generator Loss: 0.8128
# Epoch 11/100... Discriminator Loss: 1.5338... Generator Loss: 0.8445
# Epoch 12/100... Discriminator Loss: 1.4404... Generator Loss: 0.8075
# Epoch 13/100... Discriminator Loss: 1.3054... Generator Loss: 0.8166
# Epoch 14/100... Discriminator Loss: 1.6327... Generator Loss: 0.6482
# Epoch 15/100... Discriminator Loss: 1.6079... Generator Loss: 0.6603
# Epoch 16/100... Discriminator Loss: 1.6131... Generator Loss: 1.2152
# Epoch 17/100... Discriminator Loss: 1.5064... Generator Loss: 0.7843
# Epoch 18/100... Discriminator Loss: 1.4989... Generator Loss: 0.9932
# Epoch 19/100... Discriminator Loss: 0.8700... Generator Loss: 1.3156
# Epoch 20/100... Discriminator Loss: 1.2805... Generator Loss: 0.8242
# Epoch 21/100... Discriminator Loss: 1.4992... Generator Loss: 1.0466
# Epoch 22/100... Discriminator Loss: 1.7282... Generator Loss: 0.6991
# Epoch 23/100... Discriminator Loss: 1.3930... Generator Loss: 0.7999
# Epoch 24/100... Discriminator Loss: 1.2447... Generator Loss: 0.8989
# Epoch 25/100... Discriminator Loss: 1.3416... Generator Loss: 0.9339
# Epoch 26/100... Discriminator Loss: 1.1552... Generator Loss: 0.9902
# Epoch 27/100... Discriminator Loss: 1.7023... Generator Loss: 1.0577
# Epoch 28/100... Discriminator Loss: 1.5688... Generator Loss: 0.7311
# Epoch 29/100... Discriminator Loss: 1.5804... Generator Loss: 0.6901
# Epoch 30/100... Discriminator Loss: 1.0986... Generator Loss: 1.2221
# Epoch 31/100... Discriminator Loss: 1.6761... Generator Loss: 0.6472
# Epoch 32/100... Discriminator Loss: 1.3833... Generator Loss: 0.8140
# Epoch 33/100... Discriminator Loss: 1.4059... Generator Loss: 1.0872
# Epoch 34/100... Discriminator Loss: 1.5933... Generator Loss: 0.9241
# Epoch 35/100... Discriminator Loss: 1.4171... Generator Loss: 0.9434
# Epoch 36/100... Discriminator Loss: 1.0084... Generator Loss: 1.2366
# Epoch 37/100... Discriminator Loss: 0.9737... Generator Loss: 1.2700
# Epoch 38/100... Discriminator Loss: 1.3458... Generator Loss: 0.9846
# Epoch 39/100... Discriminator Loss: 2.3906... Generator Loss: 0.5279
# Epoch 40/100... Discriminator Loss: 1.2398... Generator Loss: 1.3687
# Epoch 41/100... Discriminator Loss: 2.0324... Generator Loss: 0.6862
# Epoch 42/100... Discriminator Loss: 1.2694... Generator Loss: 0.9614
# Epoch 43/100... Discriminator Loss: 2.1952... Generator Loss: 0.5905
# Epoch 44/100... Discriminator Loss: 1.3783... Generator Loss: 0.9778
# Epoch 45/100... Discriminator Loss: 1.4842... Generator Loss: 0.7968
# Epoch 46/100... Discriminator Loss: 1.5698... Generator Loss: 0.7670
# Epoch 47/100... Discriminator Loss: 1.5685... Generator Loss: 0.8157
# Epoch 48/100... Discriminator Loss: 1.6854... Generator Loss: 1.4127
# Epoch 49/100... Discriminator Loss: 1.5945... Generator Loss: 0.8078
# Epoch 50/100... Discriminator Loss: 2.0764... Generator Loss: 0.6523
# Epoch 51/100... Discriminator Loss: 1.3924... Generator Loss: 1.1098
# Epoch 52/100... Discriminator Loss: 1.5285... Generator Loss: 0.7895
# Epoch 53/100... Discriminator Loss: 1.5191... Generator Loss: 0.9845
# Epoch 54/100... Discriminator Loss: 1.3397... Generator Loss: 1.0299
# Epoch 55/100... Discriminator Loss: 1.7989... Generator Loss: 0.7065
# Epoch 56/100... Discriminator Loss: 1.5792... Generator Loss: 0.9855
# Epoch 57/100... Discriminator Loss: 1.3970... Generator Loss: 0.9370
# Epoch 58/100... Discriminator Loss: 1.5662... Generator Loss: 1.2387
# Epoch 59/100... Discriminator Loss: 1.4832... Generator Loss: 0.9134
# Epoch 60/100... Discriminator Loss: 1.8338... Generator Loss: 0.6032
# Epoch 61/100... Discriminator Loss: 1.2565... Generator Loss: 1.0266
# Epoch 62/100... Discriminator Loss: 1.2501... Generator Loss: 1.1512
# Epoch 63/100... Discriminator Loss: 1.4388... Generator Loss: 0.9939
# Epoch 64/100... Discriminator Loss: 1.4243... Generator Loss: 0.8727
# Epoch 65/100... Discriminator Loss: 1.4481... Generator Loss: 0.9111
# Epoch 66/100... Discriminator Loss: 1.3313... Generator Loss: 0.9161
# Epoch 67/100... Discriminator Loss: 1.6613... Generator Loss: 0.9351
# Epoch 68/100... Discriminator Loss: 1.1559... Generator Loss: 1.0842
# Epoch 69/100... Discriminator Loss: 1.3282... Generator Loss: 0.9634
# Epoch 70/100... Discriminator Loss: 1.2579... Generator Loss: 0.9722
# Epoch 71/100... Discriminator Loss: 1.5020... Generator Loss: 0.8036
# Epoch 72/100... Discriminator Loss: 1.3779... Generator Loss: 0.9972
# Epoch 73/100... Discriminator Loss: 1.4373... Generator Loss: 0.8525
# Epoch 74/100... Discriminator Loss: 1.7581... Generator Loss: 0.7434
# Epoch 75/100... Discriminator Loss: 1.3719... Generator Loss: 1.2279
# Epoch 76/100... Discriminator Loss: 2.1305... Generator Loss: 0.7179
# Epoch 77/100... Discriminator Loss: 1.6893... Generator Loss: 0.7986
# Epoch 78/100... Discriminator Loss: 1.3896... Generator Loss: 1.0734
# Epoch 79/100... Discriminator Loss: 1.4989... Generator Loss: 1.0241
# Epoch 80/100... Discriminator Loss: 1.4905... Generator Loss: 0.9593
# Epoch 81/100... Discriminator Loss: 1.2741... Generator Loss: 1.0073
# Epoch 82/100... Discriminator Loss: 1.3555... Generator Loss: 1.2283
# Epoch 83/100... Discriminator Loss: 1.0455... Generator Loss: 1.2902
# Epoch 84/100... Discriminator Loss: 1.3506... Generator Loss: 1.0085
# Epoch 85/100... Discriminator Loss: 1.3843... Generator Loss: 1.2258
# Epoch 86/100... Discriminator Loss: 1.3827... Generator Loss: 0.9995
# Epoch 87/100... Discriminator Loss: 1.7718... Generator Loss: 0.7935
# Epoch 88/100... Discriminator Loss: 1.5019... Generator Loss: 0.9952
# Epoch 89/100... Discriminator Loss: 1.5751... Generator Loss: 0.8580
# Epoch 90/100... Discriminator Loss: 1.1430... Generator Loss: 0.9984
# Epoch 91/100... Discriminator Loss: 1.5518... Generator Loss: 0.9158
# Epoch 92/100... Discriminator Loss: 1.3043... Generator Loss: 1.4813
# Epoch 93/100... Discriminator Loss: 1.3907... Generator Loss: 1.0922
# Epoch 94/100... Discriminator Loss: 1.3442... Generator Loss: 0.9715
# Epoch 95/100... Discriminator Loss: 1.3863... Generator Loss: 1.1131
# Epoch 96/100... Discriminator Loss: 1.2952... Generator Loss: 0.9838
# Epoch 97/100... Discriminator Loss: 1.2366... Generator Loss: 1.1597
# Epoch 98/100... Discriminator Loss: 1.3533... Generator Loss: 1.3982
# Epoch 99/100... Discriminator Loss: 0.9939... Generator Loss: 1.2862
# Epoch 100/100... Discriminator Loss: 1.3220... Generator Loss: 1.0928

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
